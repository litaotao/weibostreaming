# %%
import weibo_driver as wd

# %%
client = wd.get_local_weibo_client() or wd.get_weibo_client()

# %%
data = wd.get_data(client, count=200)

# %%
data.keys()
ids = [i.get('id', '') for i in data['statuses']]
ids
# Out:
# [3802201376186632L,
#  3802201376186461L,
#  3802201376186428L,
#  3802201375987613L,
#  3802201375987132L,
#  3802201375987053L,
#  3802201371991022L,
#  3802201371990527L,
#  3802201371990201L,
#  3802201371990172L,
#  3802201371989873L,
#  3802201371989753L,
#  3802201371989483L,
#  3802201371989423L,
#  3802201371559666L,
#  3802201371559665L,
#  3802201371559660L,
#  3802201371559515L,
#  3802201371559514L,
#  3802201371559476L,
#  3802201371188752L,
#  3802201371188673L,
#  3802201371188544L,
#  3802201371188505L,
#  3802201371188500L,
#  3802201371188461L,
#  3802201367794289L,
#  3802201367793950L,
#  3802201367793427L,
#  3802201367793345L,
#  3802201367792606L,
#  3802201367792410L,
#  3802201367792393L,
#  3802201367791959L,
#  3802201367791483L,
#  3802201367595184L,
#  3802201367594715L,
#  3802201367594676L,
#  3802201367594284L,
#  3802201367594267L,
#  3802201367594225L,
#  3802201367593952L,
#  3802201367593916L,
#  3802201367592602L,
#  3802201367592451L,
# ...

# %%
c_time = [i.get('created_at', '') for i in data['statuses']]
c_time
# Out:
# [u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:49 +0800 2015',
#  u'Fri Jan 23 15:41:52 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:48 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:50 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:50 +0800 2015',
#  u'Fri Jan 23 15:41:50 +0800 2015',
#  u'Fri Jan 23 15:41:50 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:50 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:51 +0800 2015',
#  u'Fri Jan 23 15:41:50 +0800 2015',
# ...

# %%
data
# Out:
# {'hasvisible': False,
#  'interval': 0,
#  'next_cursor': 3802184443221643L,
#  'previous_cursor': 0,
#  'statuses': [{'attitudes_count': 0,
#    'comments_count': 0,
#    'created_at': u'Fri Jan 23 14:34:33 +0800 2015',
#    'darwin_tags': [],
#    'favorited': False,
#    'geo': None,
#    'id': 3802184443851880L,
#    'idstr': u'3802184443851880',
#    'in_reply_to_screen_name': u'',
#    'in_reply_to_status_id': u'',
#    'in_reply_to_user_id': u'',
#    'mid': u'3802184443851880',
#    'mlevel': 0,
#    'pic_urls': [],
#    'reposts_count': 0,
#    'source': u'<a href="http://app.weibo.com/t/feed/6ep3Jl" rel="nofollow">\u6dd8\u5b9d\u7f51</a>',
#    'source_allowclick': 0,
#    'source_type': 1,
#    'text': u'\u5c48\u81e3\u6c0f\u7ea4\u957f\u6d53\u5bc6\u5377\u7fd8\u7535\u773c\u776b\u6bdb\u818f\u5728@\u6dd8\u5b9d\u8bd5\u7528\u4e2d\u5fc3   \u505a\u6d3b\u52a8\u54ce\uff0c\u5f88\u8d5e\u5f88\u7ed9\u529b\uff0c\u5206\u4eab\u7ed9\u5927\u5bb6\u94fe\u63a5 http://t.cn/RZHfQpP',
# ...
